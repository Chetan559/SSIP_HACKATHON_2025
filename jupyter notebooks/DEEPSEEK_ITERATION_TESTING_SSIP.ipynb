# %%
# !pip install bitsandbytes
# !pip install transformers
# !pip install accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.1/76.1 MB 9.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 45.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 28.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 27.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 97.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
# !pip install -U bitsandbytes

# %%
# !pip uninstall -y bitsandbytes
# !pip install -U bitsandbytes
# Out:
# Found existing installation: bitsandbytes 0.45.3
# Uninstalling bitsandbytes-0.45.3:
#   Successfully uninstalled bitsandbytes-0.45.3
# ...
#   Using cached bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl.metadata (5.0 kB)
# ...
# Using cached bitsandbytes-0.45.3-py3-none-manylinux_2_24_x86_64.whl (76.1 MB)
# ...

# %%
from transformers import AutoModelForCausalLM, AutoTokenizer
import bitsandbytes
tokenizer = AutoTokenizer.from_pretrained("brijesh12/deepseek-7b-chat-SSIP2")
model = AutoModelForCausalLM.from_pretrained(
    "brijesh12/deepseek-7b-chat-SSIP2",
    torch_dtype="auto",
    device_map="auto"
).to("cuda")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# tokenizer_config.json:   0%|          | 0.00/3.56k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/7.50M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/482 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/1.22k [00:00<?, ?B/s]
# Unused kwargs: ['_load_in_4bit', '_load_in_8bit', 'quant_method']. These kwargs are not used in <class 'transformers.utils.quantization_config.BitsAndBytesConfig'>.
# ...

# %%
input_text = "What is oceansat-2?"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")

output = model.generate(input_ids, max_length=2000)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:100001 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# /usr/local/lib/python3.11/dist-packages/bitsandbytes/nn/modules.py:451: UserWarning: Input type into Linear4bit is torch.float16, but bnb_4bit_compute_dtype=torch.float32 (default). This will lead to slow inference or training speed.
#   warnings.warn(
# What is oceansat-2?
# ...

# %%
input_text = "What is Kalpana-1?"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")

output = model.generate(input_ids, max_length=200)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:100001 for open-end generation.
# What is Kalpana-1?
# Kalpaana-1 is an Indian space mission that was launched on November 17, 2014. It was India's first attempt to land on the Moon and it was a part of India's Moon mission program. The mission was aimed at studying the lunar surface and to provide valuable data to India's scientific community for future space missions.
# Kalpana-1 was named after Kalpana Chawla, an Indian-American astronaut who was the first woman of Indian origin to go to space. The mission was carried out by the Indian Space Research Organisation (ISRO) and it was a collaborative effort between several institutions in India.
# ...

# %%
input_text = "What is INsat-3DR?"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")

output = model.generate(input_ids, max_length=500)
print(tokenizer.decode(output[0], skip_special_tokens=True))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:100001 for open-end generation.
# What is INsat-3DR?
# NIC-NET is a space technology organization of the Government of India, which has been given the responsibility of launching various communication satellites, earth observation satellites, meteorological satellites, navigation satellites and other scientific experiments on Indian satellite launches.
# ...

# %%
input_text = "What is mosdac.gov.in"
input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")

output = model.generate(input_ids, max_length=200)
print(tokenizer.decode(output[0], skip_special_tokens=True)) # wrong answer
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:100001 for open-end generation.
# What is mosdac.gov.in?
# mosdac.gov.in is a web portal of the Ministry of Statistics and Programme Implementation (MOSPI) in India. This portal is used for the dissemination of information on various statistical data and information related to the government’s different programs and projects.
# The Ministry of Statistics and Programme Implementation (MOSPI) is a nodal ministry in the Government of India responsible for the formulation and implementation of various statistical programs and projects. The main objective of MOSPI is to provide accurate and reliable statistical data and information to the government, policy-makers, and the general public.
# ...

# %%
# !pip install flask flask-ngrok flask-ngrok pyngrok
# !pip install flask-cors

# %% [markdown]
# ##Flask app with ngrok api key

# %%
from flask import Flask, request, jsonify
from pyngrok import ngrok
from flask_cors import CORS

# %%
app = Flask(__name__)

CORS(app, supports_credentials=True)
ngrok.set_auth_token("2leiYywqQOXyRcIykX1ZcKfLNQA_5c54v5kRVtLMeGfHqiEYy")
public_url = ngrok.connect(5000).public_url
print(" * ngrok tunnel \"{}\" -> \"http://127.0.0.1:5000/\"".format(public_url))
from google.colab.output import eval_js
print(eval_js("google.colab.kernel.proxyPort(5000)"))

@app.route('/')
def home():
    return "Welcome to the model API. Please send a POST request to /generate with 'input_text' to get a response."

@app.route('/generate', methods=['POST'])
def generate():
    # Get input text from the request
    input_data = request.get_json()

    if 'input_text' not in input_data:
        return jsonify({"error": "Please provide 'input_text' in the request"}), 400

    input_text = input_data['input_text']

    # Tokenize the input text
    input_ids = tokenizer(input_text, return_tensors="pt").input_ids.to("cuda")

    # Generate output using the model
    output = model.generate(input_ids, max_length=2000)

    # Decode the generated text and return it
    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return jsonify({"input_text": input_text, "generated_text": generated_text})

# Run the app
if __name__ == '__main__':
  app.run()
# Out:
#  * ngrok tunnel "https://ea3e-34-143-219-241.ngrok-free.app" -> "http://127.0.0.1:5000/"
# https://d9120t52so-496ff2e9c6d22116-5000-colab.googleusercontent.com/
#  * Serving Flask app '__main__'
#  * Debug mode: off
# INFO:werkzeug:WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# INFO:werkzeug:Press CTRL+C to quit
# INFO:werkzeug:127.0.0.1 - - [12/Mar/2025 13:51:42] "POST / HTTP/1.1" 405 -
# INFO:werkzeug:127.0.0.1 - - [12/Mar/2025 13:51:49] "GET / HTTP/1.1" 200 -
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:100001 for open-end generation.
# INFO:werkzeug:127.0.0.1 - - [12/Mar/2025 13:52:20] "POST /generate HTTP/1.1" 200 -
# ...
